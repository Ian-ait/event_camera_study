# %%
from ultralytics import YOLO
model = YOLO("yolo26n.yaml")
model = YOLO("yolo26n.pt")
results = model.train(data = 'coco8.yaml', epochs = 3)
results = model.val()
results = model("https://ultralytics.com/images/bus.jpg")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 6.7MB/s 0.8s.7s<0.4ss2
# Ultralytics 8.4.116  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\event_camera_study\2026-8-7_\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING Dataset 'coco8.yaml' images not found, missing path 'D:\event_camera_study\datasets\coco8\images\val'
# Downloading https://ultralytics.com/assets/coco8.zip to 'D:\event_camera_study\datasets\coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 15.2MB/s 0.0s
# Unzipping D:\event_camera_study\datasets\coco8.zip to D:\event_camera_study\datasets\coco8...: 100% ━━━━━━━━━━━━ 25/25 1.5Kfiles/s 0.0s
# Dataset download success  (1.1s), saved to D:\event_camera_study\datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\27032\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 4.2MB/s 0.2s 0.1s<0.1s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.2 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.0 ms, read: 114.955.6 MB/s, size: 50.0 KB)
# train: Scanning D:\event_camera_study\datasets\coco8\labels\train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 570.8it/s 0.0s
# train: New cache created: D:\event_camera_study\datasets\coco8\labels\train.cache
# val: Fast image access  (ping: 0.20.1 ms, read: 135.953.2 MB/s, size: 54.0 KB)
# val: Scanning D:\event_camera_study\datasets\coco8\labels\val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.3Kit/s 0.0s
# val: New cache created: D:\event_camera_study\datasets\coco8\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to D:\event_camera_study\2026-8-7_\runs\detect\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\event_camera_study\2026-8-7_\runs\detect\train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#         1/3     0.834G     0.9636      2.299    0.01337         30        640: 100% ━━━━━━━━━━━━ 1/1 7.8s/it 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.7s/it 2.7s
#                    all          4         17      0.898      0.655      0.904      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#         2/3     0.834G      1.168      2.441    0.01393         30        640: 100% ━━━━━━━━━━━━ 1/1 4.3it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 12.7it/s 0.1s
#                    all          4         17      0.898      0.655      0.904      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#         3/3     0.844G     0.9772       2.76    0.02078         16        640: 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.2it/s 0.1s
#                    all          4         17      0.876       0.67      0.904      0.665
#
# 3 epochs completed in 0.003 hours.
# Optimizer stripped from D:\event_camera_study\2026-8-7_\runs\detect\train\weights\last.pt, 5.6MB
# Optimizer stripped from D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.pt, 5.6MB
#
# Validating D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.pt...
# Ultralytics 8.4.116  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 16.1it/s 0.1s
#                    all          4         17      0.896      0.656      0.904      0.668
#                 person          3         10          1      0.436      0.781      0.396
#                    dog          1          1      0.724          1      0.995      0.597
#                  horse          1          2      0.812          1      0.995      0.795
#               elephant          1          2       0.84        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 0.4ms preprocess, 6.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to D:\event_camera_study\2026-8-7_\runs\detect\train
# Ultralytics 8.4.116  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.5 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 512.9411.0 MB/s, size: 54.0 KB)
# val: Scanning D:\event_camera_study\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.7it/s 0.1s
#                    all          4         17      0.897      0.655      0.904      0.667
#                 person          3         10          1      0.433      0.781      0.391
#                    dog          1          1      0.728          1      0.995      0.597
#                  horse          1          2      0.814          1      0.995      0.795
#               elephant          1          2      0.841        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 2.2ms preprocess, 20.1ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to D:\event_camera_study\2026-8-7_\runs\detect\val
#
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg': 100% ━━━━━━━━━━━━ 134.2KB 33.1MB/s 0.0s
# image 1/1 d:\event_camera_study\2026-8-7_\bus.jpg: 640x480 4 persons, 1 bus, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
success = model.export(format = 'onnx')
# Out:
# Ultralytics 8.4.116  Python-3.11.15 torch-2.11.0+cu128 CPU (AMD Ryzen 9 8945HX with Radeon Graphics)
#
# PyTorch: starting from 'D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.11.15 environment at: c:\Users\27032\anaconda3\envs\eventcam
# Resolved 12 packages in 936ms
# Downloading onnx (16.4MiB)
# Downloading onnxruntime (13.1MiB)
#  Downloaded onnxruntime
#  Downloaded onnx
# Prepared 6 packages in 6.88s
# Installed 6 packages in 11.00s
#  + flatbuffers==25.12.19
#  + ml-dtypes==0.5.4
#  + onnx==1.22.0
#  + onnxruntime==1.28.0
#  + onnxslim==0.1.95
#  + protobuf==7.35.1
#
# requirements: AutoUpdate success  22.3s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 20...
# ONNX: slimming with onnxslim 0.1.95...
# ONNX: export success  25.0s, saved as 'D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.onnx' (9.5 MB)
#
# Export complete (25.2s)
# Results saved to D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.onnx
# Predict:         yolo predict task=detect model=D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=D:\event_camera_study\2026-8-7_\runs\detect\train\weights\best.onnx imgsz=640 data=C:\Users\27032\anaconda3\envs\eventcam\Lib\site-packages\ultralytics\cfg\datasets\coco8.yaml
# Visualize:       https://netron.app

# %%
results = model.predict(
    source="https://ultralytics.com/images/bus.jpg",
    device=0,
    save=True
)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 d:\event_camera_study\2026-8-7_\bus.jpg: 640x480 4 persons, 1 bus, 19.1ms
# Speed: 7.1ms preprocess, 19.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to D:\event_camera_study\2026-8-7_\runs\detect\predict

# %%
print("结果保存在：", results[0].save_dir)
# Out:
# 结果保存在： D:\event_camera_study\2026-8-7_复盘＋补漏\runs\detect\predict
