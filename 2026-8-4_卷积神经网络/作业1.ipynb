# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
X = torch.arange(25).reshape((1, 1, 5, 5)).float()
conv2d = nn.Conv2d(1, 1, kernel_size = 3, padding = 1, stride = 2)
Y = conv2d(X)
print(f'输出尺寸为：{(5-3+2)/2 +1}')
print(Y.shape)
# Out:
# 输出尺寸为：3.0
# torch.Size([1, 1, 3, 3])
